# %% [markdown]
# # Credit Data Analysis
#
# * 해당 파일은 Jupyter Notebook으로 작성되었습니다.
# * 필요에 따라 colab도 사용할 예정입니다.
#
# ## 일단은 test 용입니다.
#
# ```python
# print("코드도 잘 들어가는지?")
# ```
#
# ## Finace-datareader 라이브러리 설치
# * https://github.com/FinanceData/FinanceDataReader 참고

# %%
print("hello world!")
# Out:
# hello world!

# %%
#finance-datareader 라이브러리 설치
# !pip install -U finance-datareader

# %% [markdown]
# ## FinaceDataReader로 데이터 불러오기
# * 005930(삼성전자)의 모든 주가를 확인
# * 전체 기간 : 1997~

# %%
import FinanceDataReader as fdr
df = fdr.DataReader('005930')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1997-10-04   1168   1197   1159   1197     29560       NaN
# 1997-10-06   1197   1215   1179   1185     53720 -0.010025
# 1997-10-07   1183   1183   1145   1149     68530 -0.030380
# 1997-10-08   1149   1149   1075   1076     60280 -0.063534
# 1997-10-09   1066   1097   1018   1051     96343 -0.023234
# ...           ...    ...    ...    ...       ...       ...
# 2021-10-25  69900  70600  69500  70200  10029621 -0.002841
# 2021-10-26  70600  71500  70400  71100  10528252  0.012821
# 2021-10-27  71000  71000  70000  70100  10295316 -0.014065
# 2021-10-28  69500  72200  69500  70700  20644902  0.008559
# 2021-10-29  71200  71600  69700  69800  16497812 -0.012730
#
# [6000 rows x 6 columns]
